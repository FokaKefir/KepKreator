# %% [markdown]
# <a href="https://colab.research.google.com/github/FokaKefir/KepKreator/blob/main/EMNIST_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import dependencies

# %%
import tensorflow as tf

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Conv2DTranspose, Input, Flatten, Reshape, Embedding, Concatenate
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import load_model, save_model
from tensorflow.keras.callbacks import ModelCheckpoint

import numpy as np
import matplotlib.pyplot as plt

import sys, os

# disable warnings
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# # Download EMNIST

# %%
# !pip install emnist
# Out:
# Collecting emnist
#   Downloading emnist-0.0-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from emnist) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from emnist) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from emnist) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->emnist) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->emnist) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->emnist) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->emnist) (2023.11.17)
# Installing collected packages: emnist
# Successfully installed emnist-0.0

# %%
from emnist import list_datasets
list_datasets()
# Out:
# Downloading emnist.zip: 536MB [00:05, 99.5MB/s]
# ['balanced', 'byclass', 'bymerge', 'digits', 'letters', 'mnist']

# %% [markdown]
# # Preprocess Letters dataset

# %% [markdown]
# ## Import Letters dataset

# %%
from emnist import extract_training_samples
x_train, labels_train = extract_training_samples('letters')
x_train = x_train / 255.0 * 2 - 1
labels_train = labels_train - 1

# %%
x_train.shape, labels_train.shape
# Out:
# ((124800, 28, 28), (124800,))

# %%
labels_train.min(), labels_train.max()
# Out:
# (0, 25)

# %% [markdown]
# ## Define decoder and encoder function for labels

# %%
def decode_letter(num: int):
  return chr(97 + num)
def encode_letter(letter: str):
  return ord(letter) - 97

# %%
decode_foo = decode_letter

# %% [markdown]
# ## Plot random examples

# %%
def show_images(examples, decode_fun):
  random_indices = np.random.choice(examples.shape[0], 9, replace=False)

  # rescale images (-1, +1) -> (0, 1)
  examples = 0.5 * examples + 0.5

  plt.figure(figsize=(10, 10))
  for i, index in enumerate(random_indices, 1):
      plt.subplot(3, 3, i)
      plt.imshow(x_train[index], cmap='gray')
      plt.title(f"Label: {decode_fun(labels_train[index])} ({labels_train[index]})")
      plt.axis('off')

  plt.tight_layout()
  plt.show()

show_images(x_train, decode_foo)

# %% [markdown]
# # Preprocess ByClass dataset

# %% [markdown]
# ## Import ByClass dataset

# %%
from emnist import extract_training_samples
x_train, labels_train = extract_training_samples('byclass')
x_train = x_train / 255.0 * 2 - 1

# %%
x_train.shape, labels_train.shape
# Out:
# ((697932, 28, 28), (697932,))

# %%
labels_train.min(), labels_train.max()
# Out:
# (0, 61)

# %% [markdown]
# ## Create decoder and encoder for the labels

# %%
def decode_byclass(num: int):
  if num < 10:
    return str(num)
  elif 10 <= num <= 35:
    return chr(num - 10 + 65)
  else:
    return chr(num - 36 + 97)

# %%
def encode_byclass(c: str):
  if c in '0123456789':
    return int(c)
  elif c in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
    return ord(c) - 65 + 10
  else:
    return ord(c) - 97 + 36

# %%
decode_foo = decode_byclass

# %% [markdown]
# ## Plot examples from each character

# %%
inds = []
for label in range(labels_train.max() + 1):
  index = np.where(labels_train == label)[0][0]
  inds.append(index)

# %%
plt.figure(figsize=(10, 15))
for i, index in enumerate(inds, 1):
    plt.subplot(10, 7, i)
    plt.imshow(x_train[index], cmap='gray')
    plt.title(f"Label: {decode_byclass(labels_train[index])} ({labels_train[index]})")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot random examples

# %%
def show_images(examples, decode_fun):
  random_indices = np.random.choice(examples.shape[0], 9, replace=False)

  # rescale images (-1, +1) -> (0, 1)
  examples = 0.5 * examples + 0.5

  plt.figure(figsize=(10, 10))
  for i, index in enumerate(random_indices, 1):
      plt.subplot(3, 3, i)
      plt.imshow(x_train[index], cmap='gray')
      plt.title(f"Label: {decode_fun(labels_train[index])} ({labels_train[index]})")
      plt.axis('off')

  plt.tight_layout()
  plt.show()

show_images(x_train, decode_byclass)

# %% [markdown]
# # Define model

# %%
class CGAN(tf.keras.Model):
  def __init__(self, latent_dim, n_classes=10):
    super(CGAN, self).__init__()

    self.latent_dim = latent_dim
    self.n_classes = n_classes

    # create generator
    self.generator = self.build_generator(latent_dim, n_classes)

    # create discriminator
    self.discriminator = self.build_discriminator(n_classes=n_classes)

    # add tracker
    self.gen_loss_tracker = tf.keras.metrics.Mean(name="generator_loss")
    self.disc_loss_tracker = tf.keras.metrics.Mean(name="discriminator_loss")

    tf.config.run_functions_eagerly(True)

  @property
  def metrics(self):
    return [self.gen_loss_tracker, self.disc_loss_tracker]

  def compile(self, d_optimizer, g_optimizer, loss_fn):
    # set optimizers
    self.d_optimizer = d_optimizer
    self.g_optimizer = g_optimizer

    # set loss function
    self.loss_fn = loss_fn

    super(CGAN, self).compile()

  def generate_latent_points(self, n_samples):
    x_input = np.random.randn(self.latent_dim * n_samples)
    x_input = x_input.reshape(n_samples, self.latent_dim)
    x_labels = np.random.randint(0, self.n_classes, n_samples)
    return [x_input, x_labels]

  def generate_fake_samples(self, n_samples):
    # generate points in latent space
    x_input, x_labels = self.generate_latent_points(n_samples)

    # predict outputs
    imgs = self.generator([x_input, x_labels])

    # create class labels
    y = np.zeros((n_samples, 1))
    return [imgs, x_labels], y

  def generate_images(self, x_labels):
    # generate points in latent space
    x_input, _ = self.generate_latent_points(x_labels.size)

    # predict outputs
    imgs = self.generator.predict([x_input, x_labels])

    # return generated images
    return imgs

  @tf.function
  def train_step(self, data):
    # Unpack the data
    real_images, real_labels = data

    # Get batch size
    batch_size = tf.shape(real_images)[0]

    # Get randomly selected 'real' samples, with labels
    x_real, y_real = [real_images, real_labels], np.ones((batch_size, 1))

    # Update discriminator model weights
    with tf.GradientTape() as tape:
      predictions = self.discriminator(x_real)
      d_loss_real = self.loss_fn(y_real, predictions)
    grads = tape.gradient(d_loss_real, self.discriminator.trainable_weights)
    self.d_optimizer.apply_gradients(zip(grads, self.discriminator.trainable_weights))

    # Generate 'fake' examples, with labels
    x_fake, y_fake = self.generate_fake_samples(batch_size)

    # Update discriminator model weights
    with tf.GradientTape() as tape:
      predictions = self.discriminator(x_fake)
      d_loss_fake = self.loss_fn(y_fake, predictions)
    grads = tape.gradient(d_loss_fake, self.discriminator.trainable_weights)
    self.d_optimizer.apply_gradients(zip(grads, self.discriminator.trainable_weights))

    # Calculate loss and accuracy
    d_loss = 0.5 * (d_loss_real + d_loss_fake)

    # Prepare points in latent space as input for the generator
    x_gan = self.generate_latent_points(2 * batch_size)

    # Create inverted labels for the fake samples
    y_gan = np.ones((2 * batch_size, 1))

    # Update the generator via the discriminator's error
    with tf.GradientTape() as tape:
      fake_imgs = self.generator(x_gan)
      fake_imgs_and_labels = [fake_imgs, x_gan[1]]
      predictions = self.discriminator(fake_imgs_and_labels)
      g_loss = self.loss_fn(y_gan, predictions)
    grads = tape.gradient(g_loss, self.generator.trainable_weights)
    self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

    # Monitor loss
    self.gen_loss_tracker.update_state(g_loss)
    self.disc_loss_tracker.update_state(d_loss)

    return {
        "g_loss": self.gen_loss_tracker.result(),
        "d_loss": self.disc_loss_tracker.result(),
    }


  def build_discriminator(self, in_shape=(28, 28, 1), n_classes=10):
    # label input
    i_label = Input(shape=(1, ))
    x_label = Embedding(n_classes, 50)(i_label)
    x_label = Dense(in_shape[0] * in_shape[1], activation='tanh')(x_label)
    x_label = Reshape((in_shape[0], in_shape[1], 1))(x_label)

    # image input
    i_img = Input(shape=in_shape)

    # concatenate
    x = Concatenate()([x_label, i_img])

    # conv layers
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same', activation='tanh')(i_img)
    x = Conv2D(64, (3, 3), strides=(2, 2), padding='same', activation='tanh')(x)
    x = Flatten()(x)
    x = Dense(128, activation='tanh')(x)
    x = Dropout(0.5)(x)
    x = Dense(1, activation='sigmoid')(x)

    model = Model([i_img, i_label], x)
    return model

  def build_generator(self, latent_dim, n_classes=10):
    # label input
    i_label = Input(shape=(1, ))
    x_label = Embedding(n_classes, 50)(i_label)
    x_label = Dense(7 * 7 * 3, activation='tanh')(x_label)
    x_label = Reshape((7, 7, 3))(x_label)

    # foundation for 7x7 image
    i_lat = Input(shape=(latent_dim, ))
    x_lat = Dense(7 * 7 * 125, activation='tanh')(i_lat)
    x_lat = Reshape((7, 7, 125))(x_lat)

    # concatenate
    x = Concatenate()([x_lat, x_label])

    # upsample to 14x14
    x = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', activation='tanh')(x)

    # upsample to 28x28
    x = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', activation='tanh')(x)

    # make only one color channel, values in (-1, +1)
    x = Conv2D(1, (7, 7), activation='tanh', padding='same')(x)
    return Model([i_lat, i_label], x)

  def sample_images(self, decode_fun, e=0, b=0, method='show'):
    if not os.path.exists('gan_images'):
      os.makedirs('gan_images')

    data, _ = self.generate_fake_samples(25)
    imgs, labels = data
    rows, cols = 5, 5

    # Rescale images (-1, +1) -> (0, 1)
    imgs = 0.5 * imgs + 0.5

    fig, axs = plt.subplots(rows, cols, figsize=(9, 10))
    idx = 0
    for i in range(rows):
      for j in range(cols):
        axs[i, j].imshow(imgs[idx], cmap='gray')
        axs[i, j].set_title(f"Label: {decode_fun(labels[idx])} ({labels[idx]})")
        axs[i, j].axis('off')
        idx += 1

    if method == 'show':
      plt.show()
    elif method == 'save':
      fig.savefig(f'gan_images/sample_{e:003d}_{b:0004d}.png')
      plt.close()

  # save models
  def save(self, filepath, overwrite=True, save_format=None, **kwargs):
    self.generator.save(filepath + 'generator.h5')
    self.discriminator.save(filepath + 'discriminator.h5')

  # load models
  def load_models(self, generator_path, discriminator_path):
    self.generator = load_model(generator_path, compile=False)
    self.discriminator = load_model(discriminator_path, compile=False)

# %% [markdown]
# # Train the Model

# %% [markdown]
# ## Define callbacks

# %%
checkpointer = ModelCheckpoint(
    'models/{epoch:002d}/',
    verbose=0,
    save_best_only=False,
    save_weights_only=False,
    mode='auto',
    save_freq=1000
)

# %%
class SamplerCallback(tf.keras.callbacks.Callback):
  def __init__(self, sample_freq: int=1):
    super().__init__()
    self.sample_freq = sample_freq
    self.e = 0

  def on_epoch_begin(self, epoch, logs=None):
    self.e = epoch

  def on_train_batch_end(self, batch: int, logs=None):
    if batch % self.sample_freq == 0:
      self.model.sample_images(decode_foo, self.e + 1, batch, method='save')

sampler = SamplerCallback(sample_freq=1000)

# %%
import gc

class GarbageCollectorCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    gc.collect()

garbage_collector = GarbageCollectorCallback()

# %% [markdown]
# ## Create models and train

# %%
n_classes = labels_train.max() + 1
cgan = CGAN(latent_dim=100, n_classes=n_classes)

cgan.compile(
    d_optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
    g_optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
    loss_fn=BinaryCrossentropy(from_logits=True)
)

cgan.fit(
    x_train, labels_train,
    epochs=10,
    batch_size=32,
    callbacks=[
        checkpointer,
        sampler,
        garbage_collector
    ]
)
# Out:
# Epoch 1/10
#  100/3900 [..............................] - ETA: 12:07 - g_loss: 0.9381 - d_loss: 0.4999
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3900/3900 [==============================] - 698s 178ms/step - g_loss: 0.7542 - d_loss: 0.6943
# Epoch 2/10
# 3900/3900 [==============================] - 653s 167ms/step - g_loss: 0.8626 - d_loss: 0.6405
# Epoch 3/10
# 3900/3900 [==============================] - 654s 168ms/step - g_loss: 0.8687 - d_loss: 0.6298
# Epoch 4/10
# 3900/3900 [==============================] - 661s 169ms/step - g_loss: 0.9805 - d_loss: 0.5860
# Epoch 5/10
# 3900/3900 [==============================] - 639s 164ms/step - g_loss: 1.0620 - d_loss: 0.5686
# Epoch 6/10
# 3900/3900 [==============================] - 640s 164ms/step - g_loss: 1.1296 - d_loss: 0.5499
# Epoch 7/10
# 3900/3900 [==============================] - 640s 164ms/step - g_loss: 1.2077 - d_loss: 0.5343
# Epoch 8/10
# 3900/3900 [==============================] - 640s 164ms/step - g_loss: 1.2662 - d_loss: 0.5224
# Epoch 9/10
# 3900/3900 [==============================] - 639s 164ms/step - g_loss: 1.3118 - d_loss: 0.5146
# Epoch 10/10
# 3900/3900 [==============================] - 638s 163ms/step - g_loss: 1.3533 - d_loss: 0.5081

# %% [markdown]
# # Load model

# %%
e = 1
cgan = CGAN(latent_dim=100, n_classes=n_classes)
cgan.load_models(f'models/{e:02d}/generator.h5', f'models/{e:02d}/discriminator.h5')
cgan.sample_images(decode_fun=decode_foo, method='show')

# %%
e = 3
cgan = CGAN(latent_dim=100, n_classes=n_classes)
cgan.load_models(f'models/{e:02d}/generator.h5', f'models/{e:02d}/discriminator.h5')
cgan.sample_images(decode_fun=decode_foo, method='show')

# %%
e = 5
cgan = CGAN(latent_dim=100, n_classes=n_classes)
cgan.load_models(f'models/{e:02d}/generator.h5', f'models/{e:02d}/discriminator.h5')
cgan.sample_images(decode_fun=decode_foo, method='show')

# %%
e = 7
cgan = CGAN(latent_dim=100, n_classes=n_classes)
cgan.load_models(f'models/{e:02d}/generator.h5', f'models/{e:02d}/discriminator.h5')
cgan.sample_images(decode_fun=decode_foo, method='show')

# %%
e = 9
cgan = CGAN(latent_dim=100, n_classes=n_classes)
cgan.load_models(f'models/{e:02d}/generator.h5', f'models/{e:02d}/discriminator.h5')
cgan.sample_images(decode_fun=decode_foo, method='show')

# %%
e = 10
cgan = CGAN(latent_dim=100, n_classes=n_classes)
cgan.load_models(f'models/{e:02d}/generator.h5', f'models/{e:02d}/discriminator.h5')
cgan.sample_images(decode_fun=decode_foo, method='show')

# %% [markdown]
# # Download models

# %%
# !zip -r /content/models.zip /content/models
# Out:
#   adding: content/models/ (stored 0%)
#   adding: content/models/01/ (stored 0%)
#   adding: content/models/01/discriminator.h5 (deflated 9%)
#   adding: content/models/01/generator.h5 (deflated 8%)
#   adding: content/models/07/ (stored 0%)
#   adding: content/models/07/discriminator.h5 (deflated 9%)
#   adding: content/models/07/generator.h5 (deflated 8%)
#   adding: content/models/06/ (stored 0%)
#   adding: content/models/06/discriminator.h5 (deflated 9%)
#   adding: content/models/06/generator.h5 (deflated 8%)
#   adding: content/models/09/ (stored 0%)
#   adding: content/models/09/discriminator.h5 (deflated 9%)
#   adding: content/models/09/generator.h5 (deflated 8%)
#   adding: content/models/10/ (stored 0%)
#   adding: content/models/10/discriminator.h5 (deflated 9%)
#   adding: content/models/10/generator.h5 (deflated 8%)
#   adding: content/models/03/ (stored 0%)
#   adding: content/models/03/discriminator.h5 (deflated 9%)
#   adding: content/models/03/generator.h5 (deflated 8%)
#   adding: content/models/05/ (stored 0%)
#   adding: content/models/05/discriminator.h5 (deflated 9%)
#   adding: content/models/05/generator.h5 (deflated 8%)
#   adding: content/models/02/ (stored 0%)
#   adding: content/models/02/discriminator.h5 (deflated 9%)
#   adding: content/models/02/generator.h5 (deflated 8%)
#   adding: content/models/08/ (stored 0%)
#   adding: content/models/08/discriminator.h5 (deflated 9%)
#   adding: content/models/08/generator.h5 (deflated 8%)
#   adding: content/models/04/ (stored 0%)
#   adding: content/models/04/discriminator.h5 (deflated 9%)
#   adding: content/models/04/generator.h5 (deflated 8%)

# %%
from google.colab import files
files.download("/content/models.zip")

# %%
# !ls -lS gan_images
# Out:
# total 24908
# -rw-r--r-- 1 root root 100129 Dec  9 11:12 sample_001_0000.png
# -rw-r--r-- 1 root root  70004 Dec  9 11:59 sample_005_1000.png
# -rw-r--r-- 1 root root  69874 Dec  9 11:46 sample_004_0300.png
# -rw-r--r-- 1 root root  69798 Dec  9 11:42 sample_003_2600.png
# -rw-r--r-- 1 root root  69279 Dec  9 11:58 sample_005_0700.png
# -rw-r--r-- 1 root root  68922 Dec  9 12:02 sample_005_2100.png
# -rw-r--r-- 1 root root  68792 Dec  9 11:34 sample_002_3700.png
# -rw-r--r-- 1 root root  68751 Dec  9 11:51 sample_004_2200.png
# -rw-r--r-- 1 root root  68620 Dec  9 11:52 sample_004_2400.png
# -rw-r--r-- 1 root root  68575 Dec  9 12:07 sample_006_0100.png
# -rw-r--r-- 1 root root  68519 Dec  9 12:00 sample_005_1500.png
# -rw-r--r-- 1 root root  68241 Dec  9 11:56 sample_005_0100.png
# -rw-r--r-- 1 root root  68026 Dec  9 12:17 sample_007_0000.png
# -rw-r--r-- 1 root root  67948 Dec  9 12:06 sample_005_3700.png
# -rw-r--r-- 1 root root  67940 Dec  9 11:45 sample_003_3800.png
# -rw-r--r-- 1 root root  67875 Dec  9 11:35 sample_003_0400.png
# -rw-r--r-- 1 root root  67860 Dec  9 12:35 sample_008_2700.png
# -rw-r--r-- 1 root root  67787 Dec  9 12:19 sample_007_0500.png
# -rw-r--r-- 1 root root  67762 Dec  9 12:20 sample_007_0900.png
# -rw-r--r-- 1 root root  67729 Dec  9 11:42 sample_003_2700.png
# -rw-r--r-- 1 root root  67647 Dec  9 11:43 sample_003_3300.png
# -rw-r--r-- 1 root root  67641 Dec  9 12:30 sample_008_0500.png
# -rw-r--r-- 1 root root  67619 Dec  9 12:08 sample_006_0300.png
# -rw-r--r-- 1 root root  67569 Dec  9 12:44 sample_009_1800.png
# -rw-r--r-- 1 root root  67561 Dec  9 11:53 sample_004_2700.png
# -rw-r--r-- 1 root root  67528 Dec  9 12:41 sample_009_0700.png
# -rw-r--r-- 1 root root  67472 Dec  9 12:17 sample_006_3700.png
# -rw-r--r-- 1 root root  67469 Dec  9 11:50 sample_004_1800.png
# -rw-r--r-- 1 root root  67462 Dec  9 12:25 sample_007_2800.png
# -rw-r--r-- 1 root root  67441 Dec  9 12:37 sample_008_3400.png
# -rw-r--r-- 1 root root  67440 Dec  9 12:13 sample_006_2200.png
# -rw-r--r-- 1 root root  67388 Dec  9 12:01 sample_005_1900.png
# -rw-r--r-- 1 root root  67381 Dec  9 12:36 sample_008_2900.png
# -rw-r--r-- 1 root root  67380 Dec  9 12:05 sample_005_3300.png
# -rw-r--r-- 1 root root  67335 Dec  9 12:59 sample_010_3700.png
# -rw-r--r-- 1 root root  67324 Dec  9 12:31 sample_008_1000.png
# -rw-r--r-- 1 root root  67227 Dec  9 12:09 sample_006_0800.png
# -rw-r--r-- 1 root root  67202 Dec  9 12:15 sample_006_3000.png
# -rw-r--r-- 1 root root  67191 Dec  9 12:42 sample_009_1100.png
# -rw-r--r-- 1 root root  67161 Dec  9 11:45 sample_004_0000.png
# -rw-r--r-- 1 root root  67103 Dec  9 12:15 sample_006_2900.png
# -rw-r--r-- 1 root root  67066 Dec  9 12:38 sample_008_3700.png
# -rw-r--r-- 1 root root  67065 Dec  9 12:26 sample_007_3200.png
# -rw-r--r-- 1 root root  67043 Dec  9 12:57 sample_010_2900.png
# -rw-r--r-- 1 root root  67009 Dec  9 11:33 sample_002_3300.png
# -rw-r--r-- 1 root root  66989 Dec  9 11:54 sample_004_3200.png
# -rw-r--r-- 1 root root  66947 Dec  9 12:45 sample_009_2300.png
# -rw-r--r-- 1 root root  66946 Dec  9 12:06 sample_005_3600.png
# -rw-r--r-- 1 root root  66898 Dec  9 12:11 sample_006_1700.png
# -rw-r--r-- 1 root root  66896 Dec  9 12:42 sample_009_1300.png
# -rw-r--r-- 1 root root  66864 Dec  9 11:32 sample_002_3200.png
# -rw-r--r-- 1 root root  66850 Dec  9 11:35 sample_003_0100.png
# -rw-r--r-- 1 root root  66846 Dec  9 11:50 sample_004_1600.png
# -rw-r--r-- 1 root root  66811 Dec  9 12:07 sample_006_0200.png
# -rw-r--r-- 1 root root  66794 Dec  9 12:53 sample_010_1200.png
# -rw-r--r-- 1 root root  66791 Dec  9 11:57 sample_005_0300.png
# -rw-r--r-- 1 root root  66721 Dec  9 12:11 sample_006_1400.png
# -rw-r--r-- 1 root root  66677 Dec  9 11:40 sample_003_2000.png
# -rw-r--r-- 1 root root  66637 Dec  9 12:40 sample_009_0500.png
# -rw-r--r-- 1 root root  66605 Dec  9 11:49 sample_004_1200.png
# -rw-r--r-- 1 root root  66603 Dec  9 12:56 sample_010_2300.png
# -rw-r--r-- 1 root root  66577 Dec  9 12:02 sample_005_2300.png
# -rw-r--r-- 1 root root  66567 Dec  9 12:41 sample_009_0800.png
# -rw-r--r-- 1 root root  66563 Dec  9 12:16 sample_006_3400.png
# -rw-r--r-- 1 root root  66554 Dec  9 12:19 sample_007_0400.png
# -rw-r--r-- 1 root root  66548 Dec  9 12:47 sample_009_3000.png
# -rw-r--r-- 1 root root  66543 Dec  9 12:26 sample_007_3300.png
# -rw-r--r-- 1 root root  66509 Dec  9 12:47 sample_009_3200.png
# -rw-r--r-- 1 root root  66504 Dec  9 12:01 sample_005_1700.png
# -rw-r--r-- 1 root root  66496 Dec  9 12:23 sample_007_2000.png
# -rw-r--r-- 1 root root  66471 Dec  9 12:39 sample_009_0000.png
# -rw-r--r-- 1 root root  66458 Dec  9 12:21 sample_007_1400.png
# -rw-r--r-- 1 root root  66444 Dec  9 12:04 sample_005_2800.png
# -rw-r--r-- 1 root root  66416 Dec  9 12:25 sample_007_2600.png
# -rw-r--r-- 1 root root  66410 Dec  9 12:49 sample_009_3800.png
# -rw-r--r-- 1 root root  66403 Dec  9 12:58 sample_010_3100.png
# -rw-r--r-- 1 root root  66326 Dec  9 11:36 sample_003_0700.png
# -rw-r--r-- 1 root root  66313 Dec  9 12:41 sample_009_0900.png
# -rw-r--r-- 1 root root  66312 Dec  9 11:43 sample_003_3000.png
# -rw-r--r-- 1 root root  66311 Dec  9 12:48 sample_009_3500.png
# -rw-r--r-- 1 root root  66304 Dec  9 12:30 sample_008_0600.png
# -rw-r--r-- 1 root root  66292 Dec  9 12:54 sample_010_1600.png
# -rw-r--r-- 1 root root  66203 Dec  9 12:08 sample_006_0400.png
# -rw-r--r-- 1 root root  66194 Dec  9 12:08 sample_006_0600.png
# -rw-r--r-- 1 root root  66155 Dec  9 11:52 sample_004_2300.png
# -rw-r--r-- 1 root root  66153 Dec  9 13:00 sample_010_3800.png
# -rw-r--r-- 1 root root  66152 Dec  9 11:41 sample_003_2500.png
# -rw-r--r-- 1 root root  66141 Dec  9 11:44 sample_003_3400.png
# -rw-r--r-- 1 root root  66138 Dec  9 12:04 sample_005_2700.png
# -rw-r--r-- 1 root root  66131 Dec  9 11:50 sample_004_1900.png
# -rw-r--r-- 1 root root  66121 Dec  9 12:44 sample_009_2000.png
# -rw-r--r-- 1 root root  66116 Dec  9 12:27 sample_007_3600.png
# -rw-r--r-- 1 root root  66101 Dec  9 12:32 sample_008_1500.png
# -rw-r--r-- 1 root root  66097 Dec  9 12:20 sample_007_1000.png
# -rw-r--r-- 1 root root  66074 Dec  9 12:54 sample_010_1800.png
# -rw-r--r-- 1 root root  66055 Dec  9 11:56 sample_005_0000.png
# -rw-r--r-- 1 root root  66051 Dec  9 11:53 sample_004_2800.png
# -rw-r--r-- 1 root root  66022 Dec  9 12:10 sample_006_1000.png
# -rw-r--r-- 1 root root  66014 Dec  9 12:09 sample_006_0900.png
# -rw-r--r-- 1 root root  66012 Dec  9 12:06 sample_005_3800.png
# -rw-r--r-- 1 root root  65991 Dec  9 12:48 sample_009_3400.png
# -rw-r--r-- 1 root root  65976 Dec  9 12:12 sample_006_1900.png
# -rw-r--r-- 1 root root  65972 Dec  9 11:44 sample_003_3600.png
# -rw-r--r-- 1 root root  65929 Dec  9 12:40 sample_009_0600.png
# -rw-r--r-- 1 root root  65883 Dec  9 12:26 sample_007_3100.png
# -rw-r--r-- 1 root root  65879 Dec  9 11:35 sample_003_0200.png
# -rw-r--r-- 1 root root  65873 Dec  9 12:45 sample_009_2200.png
# -rw-r--r-- 1 root root  65862 Dec  9 12:14 sample_006_2700.png
# -rw-r--r-- 1 root root  65789 Dec  9 12:52 sample_010_1100.png
# -rw-r--r-- 1 root root  65788 Dec  9 12:45 sample_009_2100.png
# -rw-r--r-- 1 root root  65783 Dec  9 11:55 sample_004_3500.png
# -rw-r--r-- 1 root root  65775 Dec  9 12:34 sample_008_2300.png
# -rw-r--r-- 1 root root  65754 Dec  9 12:12 sample_006_2100.png
# -rw-r--r-- 1 root root  65752 Dec  9 12:50 sample_010_0200.png
# -rw-r--r-- 1 root root  65735 Dec  9 11:53 sample_004_2900.png
# -rw-r--r-- 1 root root  65683 Dec  9 12:23 sample_007_1900.png
# -rw-r--r-- 1 root root  65679 Dec  9 11:46 sample_004_0200.png
# -rw-r--r-- 1 root root  65664 Dec  9 12:40 sample_009_0300.png
# -rw-r--r-- 1 root root  65660 Dec  9 12:28 sample_007_3800.png
# -rw-r--r-- 1 root root  65652 Dec  9 12:53 sample_010_1300.png
# -rw-r--r-- 1 root root  65648 Dec  9 12:30 sample_008_0800.png
# -rw-r--r-- 1 root root  65623 Dec  9 12:52 sample_010_1000.png
# -rw-r--r-- 1 root root  65617 Dec  9 12:32 sample_008_1400.png
# -rw-r--r-- 1 root root  65567 Dec  9 12:37 sample_008_3200.png
# -rw-r--r-- 1 root root  65562 Dec  9 12:59 sample_010_3600.png
# -rw-r--r-- 1 root root  65546 Dec  9 11:57 sample_005_0400.png
# -rw-r--r-- 1 root root  65544 Dec  9 12:46 sample_009_2700.png
# -rw-r--r-- 1 root root  65541 Dec  9 12:54 sample_010_1500.png
# -rw-r--r-- 1 root root  65535 Dec  9 12:18 sample_007_0300.png
# -rw-r--r-- 1 root root  65523 Dec  9 12:02 sample_005_2200.png
# -rw-r--r-- 1 root root  65506 Dec  9 11:56 sample_004_3700.png
# -rw-r--r-- 1 root root  65501 Dec  9 11:49 sample_004_1300.png
# -rw-r--r-- 1 root root  65491 Dec  9 12:44 sample_009_1900.png
# -rw-r--r-- 1 root root  65474 Dec  9 12:00 sample_005_1300.png
# -rw-r--r-- 1 root root  65428 Dec  9 12:16 sample_006_3200.png
# -rw-r--r-- 1 root root  65415 Dec  9 12:03 sample_005_2500.png
# -rw-r--r-- 1 root root  65381 Dec  9 11:37 sample_003_1000.png
# -rw-r--r-- 1 root root  65374 Dec  9 11:42 sample_003_2800.png
# -rw-r--r-- 1 root root  65319 Dec  9 12:21 sample_007_1100.png
# -rw-r--r-- 1 root root  65315 Dec  9 11:37 sample_003_0800.png
# -rw-r--r-- 1 root root  65276 Dec  9 12:58 sample_010_3000.png
# -rw-r--r-- 1 root root  65259 Dec  9 11:50 sample_004_1700.png
# -rw-r--r-- 1 root root  65241 Dec  9 12:22 sample_007_1700.png
# -rw-r--r-- 1 root root  65187 Dec  9 12:02 sample_005_2000.png
# -rw-r--r-- 1 root root  65144 Dec  9 11:34 sample_003_0000.png
# -rw-r--r-- 1 root root  65139 Dec  9 12:03 sample_005_2400.png
# -rw-r--r-- 1 root root  65121 Dec  9 11:59 sample_005_1100.png
# -rw-r--r-- 1 root root  65119 Dec  9 11:47 sample_004_0500.png
# -rw-r--r-- 1 root root  65117 Dec  9 11:34 sample_002_3800.png
# -rw-r--r-- 1 root root  65101 Dec  9 12:55 sample_010_2200.png
# -rw-r--r-- 1 root root  65059 Dec  9 11:40 sample_003_2200.png
# -rw-r--r-- 1 root root  65056 Dec  9 12:27 sample_007_3500.png
# -rw-r--r-- 1 root root  65054 Dec  9 11:48 sample_004_1000.png
# -rw-r--r-- 1 root root  65037 Dec  9 12:34 sample_008_2000.png
# -rw-r--r-- 1 root root  65021 Dec  9 11:47 sample_004_0600.png
# -rw-r--r-- 1 root root  65008 Dec  9 12:10 sample_006_1200.png
# -rw-r--r-- 1 root root  64956 Dec  9 12:18 sample_007_0200.png
# -rw-r--r-- 1 root root  64953 Dec  9 12:35 sample_008_2400.png
# -rw-r--r-- 1 root root  64948 Dec  9 12:04 sample_005_2900.png
# -rw-r--r-- 1 root root  64919 Dec  9 12:38 sample_008_3500.png
# -rw-r--r-- 1 root root  64900 Dec  9 12:10 sample_006_1300.png
# -rw-r--r-- 1 root root  64894 Dec  9 12:26 sample_007_3000.png
# -rw-r--r-- 1 root root  64870 Dec  9 11:37 sample_003_1100.png
# -rw-r--r-- 1 root root  64830 Dec  9 11:43 sample_003_3200.png
# -rw-r--r-- 1 root root  64793 Dec  9 12:05 sample_005_3400.png
# -rw-r--r-- 1 root root  64785 Dec  9 12:19 sample_007_0600.png
# -rw-r--r-- 1 root root  64764 Dec  9 11:44 sample_003_3500.png
# -rw-r--r-- 1 root root  64747 Dec  9 11:49 sample_004_1400.png
# -rw-r--r-- 1 root root  64734 Dec  9 11:47 sample_004_0800.png
# -rw-r--r-- 1 root root  64734 Dec  9 12:36 sample_008_3000.png
# -rw-r--r-- 1 root root  64717 Dec  9 12:49 sample_009_3600.png
# -rw-r--r-- 1 root root  64714 Dec  9 12:12 sample_006_2000.png
# -rw-r--r-- 1 root root  64702 Dec  9 12:15 sample_006_3100.png
# -rw-r--r-- 1 root root  64696 Dec  9 12:35 sample_008_2600.png
# -rw-r--r-- 1 root root  64679 Dec  9 11:40 sample_003_2100.png
# -rw-r--r-- 1 root root  64662 Dec  9 11:39 sample_003_1700.png
# -rw-r--r-- 1 root root  64651 Dec  9 12:51 sample_010_0400.png
# -rw-r--r-- 1 root root  64646 Dec  9 12:43 sample_009_1700.png
# -rw-r--r-- 1 root root  64632 Dec  9 12:07 sample_006_0000.png
# -rw-r--r-- 1 root root  64624 Dec  9 12:56 sample_010_2400.png
# -rw-r--r-- 1 root root  64610 Dec  9 11:38 sample_003_1500.png
# -rw-r--r-- 1 root root  64599 Dec  9 12:18 sample_007_0100.png
# -rw-r--r-- 1 root root  64591 Dec  9 12:27 sample_007_3400.png
# -rw-r--r-- 1 root root  64590 Dec  9 12:00 sample_005_1400.png
# -rw-r--r-- 1 root root  64539 Dec  9 12:01 sample_005_1600.png
# -rw-r--r-- 1 root root  64537 Dec  9 12:00 sample_005_1200.png
# -rw-r--r-- 1 root root  64516 Dec  9 12:16 sample_006_3300.png
# -rw-r--r-- 1 root root  64516 Dec  9 12:33 sample_008_1900.png
# -rw-r--r-- 1 root root  64511 Dec  9 12:03 sample_005_2600.png
# -rw-r--r-- 1 root root  64503 Dec  9 11:31 sample_002_2900.png
# -rw-r--r-- 1 root root  64458 Dec  9 11:58 sample_005_0500.png
# -rw-r--r-- 1 root root  64448 Dec  9 12:33 sample_008_1700.png
# -rw-r--r-- 1 root root  64416 Dec  9 11:55 sample_004_3600.png
# -rw-r--r-- 1 root root  64411 Dec  9 12:13 sample_006_2400.png
# -rw-r--r-- 1 root root  64402 Dec  9 12:50 sample_010_0300.png
# -rw-r--r-- 1 root root  64391 Dec  9 11:54 sample_004_3100.png
# -rw-r--r-- 1 root root  64339 Dec  9 12:33 sample_008_1800.png
# -rw-r--r-- 1 root root  64327 Dec  9 11:40 sample_003_1900.png
# -rw-r--r-- 1 root root  64321 Dec  9 12:56 sample_010_2500.png
# -rw-r--r-- 1 root root  64292 Dec  9 11:54 sample_004_3000.png
# -rw-r--r-- 1 root root  64289 Dec  9 11:52 sample_004_2500.png
# -rw-r--r-- 1 root root  64284 Dec  9 11:45 sample_004_0100.png
# -rw-r--r-- 1 root root  64284 Dec  9 12:55 sample_010_2000.png
# -rw-r--r-- 1 root root  64210 Dec  9 11:38 sample_003_1400.png
# -rw-r--r-- 1 root root  64209 Dec  9 11:54 sample_004_3300.png
# -rw-r--r-- 1 root root  64186 Dec  9 11:57 sample_005_0200.png
# -rw-r--r-- 1 root root  64182 Dec  9 11:43 sample_003_3100.png
# -rw-r--r-- 1 root root  64176 Dec  9 12:37 sample_008_3100.png
# -rw-r--r-- 1 root root  64138 Dec  9 12:09 sample_006_0700.png
# -rw-r--r-- 1 root root  64127 Dec  9 12:58 sample_010_3300.png
# -rw-r--r-- 1 root root  64115 Dec  9 11:55 sample_004_3400.png
# -rw-r--r-- 1 root root  64113 Dec  9 11:52 sample_004_2600.png
# -rw-r--r-- 1 root root  64113 Dec  9 12:38 sample_008_3800.png
# -rw-r--r-- 1 root root  64092 Dec  9 12:24 sample_007_2400.png
# -rw-r--r-- 1 root root  64083 Dec  9 12:14 sample_006_2600.png
# -rw-r--r-- 1 root root  64082 Dec  9 12:29 sample_008_0400.png
# -rw-r--r-- 1 root root  64044 Dec  9 12:23 sample_007_2100.png
# -rw-r--r-- 1 root root  64043 Dec  9 12:11 sample_006_1600.png
# -rw-r--r-- 1 root root  64040 Dec  9 12:43 sample_009_1500.png
# -rw-r--r-- 1 root root  64023 Dec  9 12:32 sample_008_1300.png
# -rw-r--r-- 1 root root  64022 Dec  9 11:37 sample_003_0900.png
# -rw-r--r-- 1 root root  63985 Dec  9 11:56 sample_004_3800.png
# -rw-r--r-- 1 root root  63985 Dec  9 12:57 sample_010_2800.png
# -rw-r--r-- 1 root root  63981 Dec  9 12:34 sample_008_2200.png
# -rw-r--r-- 1 root root  63953 Dec  9 12:42 sample_009_1200.png
# -rw-r--r-- 1 root root  63950 Dec  9 12:22 sample_007_1500.png
# -rw-r--r-- 1 root root  63950 Dec  9 12:38 sample_008_3600.png
# -rw-r--r-- 1 root root  63925 Dec  9 12:11 sample_006_1500.png
# -rw-r--r-- 1 root root  63922 Dec  9 12:08 sample_006_0500.png
# -rw-r--r-- 1 root root  63913 Dec  9 12:31 sample_008_0900.png
# -rw-r--r-- 1 root root  63884 Dec  9 12:46 sample_009_2800.png
# -rw-r--r-- 1 root root  63883 Dec  9 12:25 sample_007_2700.png
# -rw-r--r-- 1 root root  63864 Dec  9 11:41 sample_003_2300.png
# -rw-r--r-- 1 root root  63862 Dec  9 12:29 sample_008_0300.png
# -rw-r--r-- 1 root root  63833 Dec  9 12:47 sample_009_3100.png
# -rw-r--r-- 1 root root  63772 Dec  9 12:04 sample_005_3000.png
# -rw-r--r-- 1 root root  63768 Dec  9 12:28 sample_008_0100.png
# -rw-r--r-- 1 root root  63763 Dec  9 12:28 sample_008_0000.png
# -rw-r--r-- 1 root root  63762 Dec  9 12:59 sample_010_3400.png
# -rw-r--r-- 1 root root  63731 Dec  9 11:48 sample_004_1100.png
# -rw-r--r-- 1 root root  63725 Dec  9 12:33 sample_008_1600.png
# -rw-r--r-- 1 root root  63717 Dec  9 11:39 sample_003_1600.png
# -rw-r--r-- 1 root root  63686 Dec  9 12:34 sample_008_2100.png
# -rw-r--r-- 1 root root  63660 Dec  9 12:25 sample_007_2900.png
# -rw-r--r-- 1 root root  63617 Dec  9 12:48 sample_009_3300.png
# -rw-r--r-- 1 root root  63611 Dec  9 12:42 sample_009_1000.png
# -rw-r--r-- 1 root root  63594 Dec  9 11:45 sample_003_3700.png
# -rw-r--r-- 1 root root  63594 Dec  9 12:28 sample_007_3700.png
# -rw-r--r-- 1 root root  63573 Dec  9 11:36 sample_003_0500.png
# -rw-r--r-- 1 root root  63563 Dec  9 12:31 sample_008_1200.png
# -rw-r--r-- 1 root root  63561 Dec  9 11:33 sample_002_3500.png
# -rw-r--r-- 1 root root  63542 Dec  9 12:55 sample_010_1900.png
# -rw-r--r-- 1 root root  63478 Dec  9 11:35 sample_003_0300.png
# -rw-r--r-- 1 root root  63433 Dec  9 11:49 sample_004_1500.png
# -rw-r--r-- 1 root root  63410 Dec  9 12:05 sample_005_3200.png
# -rw-r--r-- 1 root root  63323 Dec  9 11:58 sample_005_0800.png
# -rw-r--r-- 1 root root  63280 Dec  9 12:47 sample_009_2900.png
# -rw-r--r-- 1 root root  63257 Dec  9 11:59 sample_005_0900.png
# -rw-r--r-- 1 root root  63248 Dec  9 12:17 sample_006_3600.png
# -rw-r--r-- 1 root root  63241 Dec  9 12:22 sample_007_1600.png
# -rw-r--r-- 1 root root  63215 Dec  9 11:38 sample_003_1300.png
# -rw-r--r-- 1 root root  63154 Dec  9 12:13 sample_006_2300.png
# -rw-r--r-- 1 root root  63125 Dec  9 12:12 sample_006_1800.png
# -rw-r--r-- 1 root root  63090 Dec  9 11:48 sample_004_0900.png
# -rw-r--r-- 1 root root  63073 Dec  9 12:16 sample_006_3500.png
# -rw-r--r-- 1 root root  63054 Dec  9 11:42 sample_003_2900.png
# -rw-r--r-- 1 root root  63052 Dec  9 12:01 sample_005_1800.png
# -rw-r--r-- 1 root root  63028 Dec  9 11:46 sample_004_0400.png
# -rw-r--r-- 1 root root  63020 Dec  9 11:38 sample_003_1200.png
# -rw-r--r-- 1 root root  62986 Dec  9 12:50 sample_010_0100.png
# -rw-r--r-- 1 root root  62945 Dec  9 12:37 sample_008_3300.png
# -rw-r--r-- 1 root root  62913 Dec  9 12:52 sample_010_0800.png
# -rw-r--r-- 1 root root  62912 Dec  9 12:56 sample_010_2600.png
# -rw-r--r-- 1 root root  62835 Dec  9 12:49 sample_010_0000.png
# -rw-r--r-- 1 root root  62822 Dec  9 12:23 sample_007_2200.png
# -rw-r--r-- 1 root root  62780 Dec  9 12:14 sample_006_2500.png
# -rw-r--r-- 1 root root  62777 Dec  9 12:17 sample_006_3800.png
# -rw-r--r-- 1 root root  62771 Dec  9 12:14 sample_006_2800.png
# -rw-r--r-- 1 root root  62736 Dec  9 12:40 sample_009_0400.png
# -rw-r--r-- 1 root root  62731 Dec  9 12:51 sample_010_0600.png
# -rw-r--r-- 1 root root  62683 Dec  9 11:39 sample_003_1800.png
# -rw-r--r-- 1 root root  62674 Dec  9 11:32 sample_002_3100.png
# -rw-r--r-- 1 root root  62647 Dec  9 12:24 sample_007_2300.png
# -rw-r--r-- 1 root root  62644 Dec  9 11:58 sample_005_0600.png
# -rw-r--r-- 1 root root  62595 Dec  9 11:32 sample_002_3000.png
# -rw-r--r-- 1 root root  62562 Dec  9 12:46 sample_009_2600.png
# -rw-r--r-- 1 root root  62556 Dec  9 12:29 sample_008_0200.png
# -rw-r--r-- 1 root root  62529 Dec  9 12:19 sample_007_0700.png
# -rw-r--r-- 1 root root  62517 Dec  9 12:36 sample_008_2800.png
# -rw-r--r-- 1 root root  62515 Dec  9 12:10 sample_006_1100.png
# -rw-r--r-- 1 root root  62508 Dec  9 12:53 sample_010_1400.png
# -rw-r--r-- 1 root root  62488 Dec  9 12:20 sample_007_0800.png
# -rw-r--r-- 1 root root  62433 Dec  9 11:33 sample_002_3600.png
# -rw-r--r-- 1 root root  62417 Dec  9 12:39 sample_009_0200.png
# -rw-r--r-- 1 root root  62372 Dec  9 12:21 sample_007_1300.png
# -rw-r--r-- 1 root root  62344 Dec  9 12:43 sample_009_1400.png
# -rw-r--r-- 1 root root  62309 Dec  9 12:24 sample_007_2500.png
# -rw-r--r-- 1 root root  62284 Dec  9 11:47 sample_004_0700.png
# -rw-r--r-- 1 root root  62271 Dec  9 11:51 sample_004_2100.png
# -rw-r--r-- 1 root root  62262 Dec  9 12:30 sample_008_0700.png
# -rw-r--r-- 1 root root  62247 Dec  9 12:57 sample_010_2700.png
# -rw-r--r-- 1 root root  62168 Dec  9 12:49 sample_009_3700.png
# -rw-r--r-- 1 root root  62138 Dec  9 12:51 sample_010_0500.png
# -rw-r--r-- 1 root root  62117 Dec  9 12:05 sample_005_3100.png
# -rw-r--r-- 1 root root  62044 Dec  9 12:43 sample_009_1600.png
# -rw-r--r-- 1 root root  62033 Dec  9 11:36 sample_003_0600.png
# -rw-r--r-- 1 root root  61991 Dec  9 12:58 sample_010_3200.png
# -rw-r--r-- 1 root root  61671 Dec  9 11:33 sample_002_3400.png
# -rw-r--r-- 1 root root  61650 Dec  9 12:51 sample_010_0700.png
# -rw-r--r-- 1 root root  61519 Dec  9 12:46 sample_009_2500.png
# -rw-r--r-- 1 root root  61493 Dec  9 12:31 sample_008_1100.png
# -rw-r--r-- 1 root root  61330 Dec  9 12:45 sample_009_2400.png
# -rw-r--r-- 1 root root  61315 Dec  9 12:22 sample_007_1800.png
# -rw-r--r-- 1 root root  61224 Dec  9 11:30 sample_002_2400.png
# -rw-r--r-- 1 root root  61207 Dec  9 11:30 sample_002_2300.png
# -rw-r--r-- 1 root root  61166 Dec  9 12:55 sample_010_2100.png
# -rw-r--r-- 1 root root  61148 Dec  9 11:31 sample_002_2700.png
# -rw-r--r-- 1 root root  61116 Dec  9 11:51 sample_004_2000.png
# -rw-r--r-- 1 root root  61108 Dec  9 11:31 sample_002_2600.png
# -rw-r--r-- 1 root root  61057 Dec  9 12:52 sample_010_0900.png
# -rw-r--r-- 1 root root  60765 Dec  9 12:35 sample_008_2500.png
# -rw-r--r-- 1 root root  60590 Dec  9 11:31 sample_002_2800.png
# -rw-r--r-- 1 root root  60489 Dec  9 12:06 sample_005_3500.png
# -rw-r--r-- 1 root root  60471 Dec  9 12:59 sample_010_3500.png
# -rw-r--r-- 1 root root  60445 Dec  9 12:21 sample_007_1200.png
# -rw-r--r-- 1 root root  60431 Dec  9 12:39 sample_009_0100.png
# -rw-r--r-- 1 root root  60267 Dec  9 11:29 sample_002_2100.png
# -rw-r--r-- 1 root root  60259 Dec  9 11:28 sample_002_1800.png
# -rw-r--r-- 1 root root  59905 Dec  9 11:30 sample_002_2500.png
# -rw-r--r-- 1 root root  59375 Dec  9 11:21 sample_001_3200.png
# -rw-r--r-- 1 root root  59180 Dec  9 11:41 sample_003_2400.png
# -rw-r--r-- 1 root root  59112 Dec  9 11:22 sample_001_3500.png
# -rw-r--r-- 1 root root  59095 Dec  9 11:20 sample_001_2800.png
# -rw-r--r-- 1 root root  58943 Dec  9 11:29 sample_002_2000.png
# -rw-r--r-- 1 root root  58760 Dec  9 11:19 sample_001_2500.png
# -rw-r--r-- 1 root root  58539 Dec  9 11:28 sample_002_1600.png
# -rw-r--r-- 1 root root  58502 Dec  9 11:21 sample_001_3100.png
# -rw-r--r-- 1 root root  57772 Dec  9 11:30 sample_002_2200.png
# -rw-r--r-- 1 root root  57590 Dec  9 11:20 sample_001_2700.png
# -rw-r--r-- 1 root root  57329 Dec  9 11:17 sample_001_1500.png
# -rw-r--r-- 1 root root  57028 Dec  9 11:29 sample_002_1900.png
# -rw-r--r-- 1 root root  56792 Dec  9 11:27 sample_002_1200.png
# -rw-r--r-- 1 root root  56720 Dec  9 11:23 sample_001_3700.png
# -rw-r--r-- 1 root root  56639 Dec  9 11:19 sample_001_2400.png
# -rw-r--r-- 1 root root  56479 Dec  9 11:28 sample_002_1500.png
# -rw-r--r-- 1 root root  56218 Dec  9 11:20 sample_001_2600.png
# -rw-r--r-- 1 root root  56190 Dec  9 11:25 sample_002_0700.png
# -rw-r--r-- 1 root root  56135 Dec  9 11:19 sample_001_2300.png
# -rw-r--r-- 1 root root  55737 Dec  9 11:26 sample_002_1100.png
# -rw-r--r-- 1 root root  55717 Dec  9 11:17 sample_001_1600.png
# -rw-r--r-- 1 root root  55698 Dec  9 11:18 sample_001_1900.png
# -rw-r--r-- 1 root root  55623 Dec  9 11:27 sample_002_1300.png
# -rw-r--r-- 1 root root  55174 Dec  9 12:54 sample_010_1700.png
# -rw-r--r-- 1 root root  55169 Dec  9 11:18 sample_001_2000.png
# -rw-r--r-- 1 root root  55124 Dec  9 11:27 sample_002_1400.png
# -rw-r--r-- 1 root root  55017 Dec  9 11:17 sample_001_1800.png
# -rw-r--r-- 1 root root  54966 Dec  9 11:21 sample_001_2900.png
# -rw-r--r-- 1 root root  54836 Dec  9 11:25 sample_002_0500.png
# -rw-r--r-- 1 root root  54580 Dec  9 11:19 sample_001_2200.png
# -rw-r--r-- 1 root root  54445 Dec  9 11:18 sample_001_2100.png
# -rw-r--r-- 1 root root  54391 Dec  9 11:28 sample_002_1700.png
# -rw-r--r-- 1 root root  54224 Dec  9 11:12 sample_001_0100.png
# -rw-r--r-- 1 root root  54082 Dec  9 11:13 sample_001_0300.png
# -rw-r--r-- 1 root root  53903 Dec  9 11:26 sample_002_1000.png
# -rw-r--r-- 1 root root  53837 Dec  9 11:15 sample_001_1100.png
# -rw-r--r-- 1 root root  53552 Dec  9 11:16 sample_001_1400.png
# -rw-r--r-- 1 root root  53505 Dec  9 11:22 sample_001_3300.png
# -rw-r--r-- 1 root root  53340 Dec  9 11:16 sample_001_1300.png
# -rw-r--r-- 1 root root  53125 Dec  9 11:13 sample_001_0400.png
# -rw-r--r-- 1 root root  53039 Dec  9 11:23 sample_001_3800.png
# -rw-r--r-- 1 root root  52905 Dec  9 11:21 sample_001_3000.png
# -rw-r--r-- 1 root root  52683 Dec  9 11:16 sample_001_1200.png
# -rw-r--r-- 1 root root  52669 Dec  9 11:14 sample_001_0900.png
# -rw-r--r-- 1 root root  52490 Dec  9 11:26 sample_002_0900.png
# -rw-r--r-- 1 root root  52355 Dec  9 11:23 sample_002_0000.png
# -rw-r--r-- 1 root root  52272 Dec  9 11:25 sample_002_0600.png
# -rw-r--r-- 1 root root  52236 Dec  9 11:17 sample_001_1700.png
# -rw-r--r-- 1 root root  52222 Dec  9 11:15 sample_001_1000.png
# -rw-r--r-- 1 root root  52206 Dec  9 11:13 sample_001_0500.png
# -rw-r--r-- 1 root root  51481 Dec  9 11:14 sample_001_0600.png
# -rw-r--r-- 1 root root  51385 Dec  9 11:22 sample_001_3400.png
# -rw-r--r-- 1 root root  51115 Dec  9 11:23 sample_001_3600.png
# -rw-r--r-- 1 root root  51085 Dec  9 11:24 sample_002_0200.png
# -rw-r--r-- 1 root root  50902 Dec  9 11:12 sample_001_0200.png
# -rw-r--r-- 1 root root  50462 Dec  9 11:14 sample_001_0700.png
# -rw-r--r-- 1 root root  50300 Dec  9 11:14 sample_001_0800.png
# -rw-r--r-- 1 root root  49746 Dec  9 11:24 sample_002_0100.png
# -rw-r--r-- 1 root root  49724 Dec  9 11:24 sample_002_0300.png
# -rw-r--r-- 1 root root  49665 Dec  9 11:26 sample_002_0800.png
# -rw-r--r-- 1 root root  49451 Dec  9 11:24 sample_002_0400.png
